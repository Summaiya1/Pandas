# %%
data = pd.read_csv('TAXRATES1.csv',header = None) # header nahi banaaya bs 0 1 2 3 4

# %%
import pandas as pd

# %%
data
# Out:
#      0      1        2                  3          4                      5  \
# 0  NaN  State  ZipCode      TaxRegionName  StateRate  EstimatedCombinedRate
# 1  0.0     AK      one  ANCHORAGE BOROUGH          0                      0
# 2  1.0     AK      one  ANCHORAGE BOROUGH          0                    NaN
# 3  2.0     AK      two  ANCHORAGE BOROUGH          0                      0
# 4  3.0     AK      two  ANCHORAGE BOROUGH        NaN                      0
#
#                      6                  7                     8          9
# 0  EstimatedCountyRate  EstimatedCityRate  EstimatedSpecialRate  RiskLevel
# 1                    0                NaN                     0          1
# 2                    0                  0                     0          2
# 3                  NaN                  0                   NaN          3
# 4                    0                  0                     0          4

# %%
data1 = pd.read_csv('XihrWA.csv',header = None)

# %%
data1
# Out:
#         0        1                  2          3                      4  \
# 0   State  ZipCode      TaxRegionName  StateRate  EstimatedCombinedRate
# 1      AK      one  ANCHORAGE BOROUGH          0                      0
# 2      AK      one  ANCHORAGE BOROUGH          0                    NaN
# 3      AK      two  ANCHORAGE BOROUGH          0                      0
# 4      AK      two  ANCHORAGE BOROUGH        NaN                      0
# 5      AK      two  ANCHORAGE BOROUGH          0                      0
# 6      AK      two  ANCHORAGE BOROUGH        NaN                      0
# 7      AK      two  ANCHORAGE BOROUGH          0                      0
# 8      AK      two  ANCHORAGE BOROUGH        NaN                      0
# 9      AK      two  ANCHORAGE BOROUGH          0                      0
# 10     AK      two  ANCHORAGE BOROUGH        NaN                      0
# 11     AK      two  ANCHORAGE BOROUGH          0                      0
# ...

# %%
data1 = pd.read_csv('XihrWA.csv',names = ['a','b','c','d','e','f','g','h','i'])

# %%
data1
# Out:
#         a        b                  c          d                      e  \
# 0   State  ZipCode      TaxRegionName  StateRate  EstimatedCombinedRate
# 1      AK      one  ANCHORAGE BOROUGH          0                      0
# 2      AK      one  ANCHORAGE BOROUGH          0                    NaN
# 3      AK      two  ANCHORAGE BOROUGH          0                      0
# 4      AK      two  ANCHORAGE BOROUGH        NaN                      0
# 5      AK      two  ANCHORAGE BOROUGH          0                      0
# 6      AK      two  ANCHORAGE BOROUGH        NaN                      0
# 7      AK      two  ANCHORAGE BOROUGH          0                      0
# 8      AK      two  ANCHORAGE BOROUGH        NaN                      0
# 9      AK      two  ANCHORAGE BOROUGH          0                      0
# 10     AK      two  ANCHORAGE BOROUGH        NaN                      0
# 11     AK      two  ANCHORAGE BOROUGH          0                      0
# ...

# %%
data1 = pd.read_csv('XihrWA.csv',names = ['a','b','c','d','e','f','g','h','i'],index_col = 'i') # i kay column ko index banadia i.e
# risk level ko

# %%
data1
# Out:
#                a        b                  c          d  \
# i
# RiskLevel  State  ZipCode      TaxRegionName  StateRate
# 1             AK      one  ANCHORAGE BOROUGH          0
# 2             AK      one  ANCHORAGE BOROUGH          0
# 3             AK      two  ANCHORAGE BOROUGH          0
# 4             AK      two  ANCHORAGE BOROUGH        NaN
# 5             AK      two  ANCHORAGE BOROUGH          0
# 6             AK      two  ANCHORAGE BOROUGH        NaN
# 7             AK      two  ANCHORAGE BOROUGH          0
# 8             AK      two  ANCHORAGE BOROUGH        NaN
# 9             AK      two  ANCHORAGE BOROUGH          0
# 10            AK      two  ANCHORAGE BOROUGH        NaN
# 11            AK      two  ANCHORAGE BOROUGH          0
# 12            AK      two  ANCHORAGE BOROUGH        NaN
# 13            AK      two  ANCHORAGE BOROUGH          0
# 14            AK      two  ANCHORAGE BOROUGH        NaN
# 15            AK      two  ANCHORAGE BOROUGH          0
#
# ...

# %%
data1 = pd.read_csv('XihrWA.csv',index_col = ['ZipCode', 'RiskLevel'])
data1
# Out:
#                   State      TaxRegionName  StateRate  EstimatedCombinedRate  \
# ZipCode RiskLevel
# one     1            AK  ANCHORAGE BOROUGH        0.0                    0.0
#         2            AK  ANCHORAGE BOROUGH        0.0                    NaN
# two     3            AK  ANCHORAGE BOROUGH        0.0                    0.0
#         4            AK  ANCHORAGE BOROUGH        NaN                    0.0
#         5            AK  ANCHORAGE BOROUGH        0.0                    0.0
#         6            AK  ANCHORAGE BOROUGH        NaN                    0.0
#         7            AK  ANCHORAGE BOROUGH        0.0                    0.0
#         8            AK  ANCHORAGE BOROUGH        NaN                    0.0
#         9            AK  ANCHORAGE BOROUGH        0.0                    0.0
#         10           AK  ANCHORAGE BOROUGH        NaN                    0.0
#         11           AK  ANCHORAGE BOROUGH        0.0                    0.0
# ...

# %%
pd.isnull(data1) # false yeh value null nhi  hae
# true means null hae

# %%
data1[pd.isnull(data1)] # jo nan value hae wo agaya

# %%
data1 = pd.read_csv('XihrWA.csv',na_values=[0]) # jo value 0 hae ussay NAN kardeaga

# %%
data1

# %%
pd.read_csv('XihrWA.csv',nrows = 2) # 2 rows read karee # 1 row ko header consider kia

# %%
chunkread = pd.read_csv('XihrWA.csv',chunksize = 2) # 2 rows karkay read

# %%
chunkread # is a handler object # can acees by iteration
           # chunksize say files mein thora thora data save karsaktay haen

# %%
for i in chunkread:
    print(i)
    print('***************************************************************')

# %%
import csv

f = open('XihrWA.csv') # without pandas
reader = csv.reader(f)
list(reader)  # to read it , we can use for loop or list

# we must close this file other wise errors may occur 
# with open automaticalluy closes file

# %%
for line in reader: print(line)

# %%
with open('XihrWA.csv') as f:
    lines = list(csv.reader(f))

# %%
# saray data ko dictionary mein convert karna hae
# aj kal data zyada tarr json mein hota hae
# jason mein jo keys hotee haen wo saree keys mein hotee haen
# bs dictionary mein keys numeric bhi hotee haen
#  isliyaa json and dict are same

# %%
header , values = lines[0] , lines[1:]
header

# %%
# packing
a= 1,2
a

# %%
# unpacking

a,b = 1,2
print(a)
print(b)

# %%
print(*values)

# %%
data_dict = {h:v for h,v in zip(header,zip(*values))} # zip haer iteration mein say phele value uthayga
data_dict

# %%
data_dict = {h:v for h,v in zip(header,zip(values))} # zip haer iteration mein say phele value uthayga
data_dict

# %%
a = [1,2,3]
b = ['a','b','c']
c = zip(a,b)
list(c)

# %%
#JSON supports every language
# key value pair
# JSON is no sql beacuse it dont have tables

# %%
obj = """
{"name": "Wes",
"places_lived": ["United States", "Spain", "Germany"],
"pet": null,
"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},
{"name": "Katie", "age": 38,
"pets": ["Sixes", "Stache", "Cisco"]}]
}
""" 
# json mein dta bhejnay kay liyaya phelay string mein kardia
# yeh issay comments treat huay tou inko complie nhi karay ga
print(obj)

# %%
print(type(obj))

# %%
obj = {"name": "Wes","places_lived": ["United States", "Spain", "Germany"],"pet": null,"siblings": [{"name": "Scott", "age": 30, "pets": ["Zeus", "Zuko"]},{"name": "Katie", "age": 38,"pets": ["Sixes", "Stache", "Cisco"]}]}
print(obj)

# %%
import json

# %%
result = json.loads(obj) # python dict mein convert
print(result)
print(type(result))

# %%
asjson = json.dumps(result) # json ki file mein string daal dia # front end say string mein lay lia phir ussay backend mein dictionary mein hee laelaingay 
print(asjson)
print(type(asjson))

# %%
fwf = pd.read_fwf('XihrWA.csv') # fixed with format # no delimiter consider

# %%
fwf
# Out:
#    State,ZipCode,TaxRegionName,StateRate,EstimatedCombinedRate,EstimatedCountyRate,EstimatedCityRate,EstimatedSpecialRate,RiskLevel
# 0                 AK,one,ANCHORAGE BOROUGH,0,0,0,,0,1
# 1                 AK,one,ANCHORAGE BOROUGH,0,,0,0,0,2
# 2                  AK,two,ANCHORAGE BOROUGH,0,0,,0,,3
# 3                 AK,two,ANCHORAGE BOROUGH,,0,0,0,0,4
# 4                  AK,two,ANCHORAGE BOROUGH,0,0,,0,,5
# 5                 AK,two,ANCHORAGE BOROUGH,,0,0,0,0,6
# 6                  AK,two,ANCHORAGE BOROUGH,0,0,,0,,7
# 7                 AK,two,ANCHORAGE BOROUGH,,0,0,0,0,8
# 8                  AK,two,ANCHORAGE BOROUGH,0,0,,0,,9
# 9                AK,two,ANCHORAGE BOROUGH,,0,0,0,0,10
# 10                AK,two,ANCHORAGE BOROUGH,0,0,,0,,11
# 11               AK,two,ANCHORAGE BOROUGH,,0,0,0,0,12
# 12                AK,two,ANCHORAGE BOROUGH,0,0,,0,,13
# 13               AK,two,ANCHORAGE BOROUGH,,0,0,0,0,14
# 14                AK,two,ANCHORAGE BOROUGH,0,0,,0,,15

# %%
clip = pd.read_clipboard() # jo cheez copy karee we hogee uskoo save karkay dataframe mein show karay ga
clip
# Out:
# Empty DataFrame
# Columns: ['XihrWA.csv']
# Index: []

# %%
df = pd.DataFrame([[1,1.0,'a']],columns = ['x','y','z'])
df
df.to_hdf('./store.h5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-54cd22da382b> in <module>
#       1 df = pd.DataFrame([[1,1.0,'a']],columns = ['x','y','z'])
#       2 df
# ----> 3 df.to_hdf('./store.h5')
#
# TypeError: to_hdf() missing 1 required positional argument: 'key'

# %%
# %load index.html # run this funtion to get html file code

# %%
# %load index.html
<!DOCTYPE html>
<html>
<head>
<style>
table {
  font-family: arial, sans-serif;
  border-collapse: collapse;
  width: 100%;
}

td, th {
  border: 1px solid #dddddd;
  text-align: left;
  padding: 8px;
}

tr:nth-child(even) {
  background-color: #dddddd;
}
</style>
</head>
<body>

<h2>HTML Table</h2>

<table>
  <tr>
    <th>Company</th>
    <th>Contact</th>
    <th>Country</th>
  </tr>
  <tr>
    <td>Alfreds</td>
    <td>Maria</td>
    <td>Germany</td>
  </tr>
  <tr>
    <td>Centro</td>
    <td>Francisco</td>
    <td>Mexico</td>
  </tr>
  <tr>
    <td>Ernst</td>
    <td>Roland</td>
    <td>Austria</td>
  </tr>
  <tr>
    <td>Island</td>
    <td>Helen</td>
    <td>UK</td>
  </tr>
  <tr>
    <td>Laughing</td>
    <td>Yoshi</td>
    <td>Canada</td>
  </tr>
  <tr>
    <td>Magazzini</td>
    <td>Giovanni</td>
    <td>Italy</td>
  </tr>
</table>

</body>
</html>

# %%
htmlreader = pd.read_html('index.html') # sirf html page kaa table uthaa kar lay aygaaa
htmlreader
# Out:
# [     Company    Contact  Country
#  0    Alfreds      Maria  Germany
#  1     Centro  Francisco   Mexico
#  2      Ernst     Roland  Austria
#  3     Island      Helen       UK
#  4   Laughing      Yoshi   Canada
#  5  Magazzini   Giovanni    Italy]

# %%
# %load data.json # run this command to get json data

# %%
# %load data.json # json ka data load kardia 
{"columns":["col 1","col 2"],
  "index":["row 1","row 2"],
  "data":[["a","b"],["c","d"]]}

# %%
readJson = pd.read_json('data.json')
readJson
# Out:
#   columns  index    data
# 0   col 1  row 1  [a, b]
# 1   col 2  row 2  [c, d]

# %% [markdown]
# # Web Scraping

# %%
# data  collect from different websites
# haer website scraping allow nhi kartee
# first we check it
# website per jo images aur links jo hotee haen wo chahiyaya
# API say public data mil jata hae
# API har koi nhi daeta tou public data kesay laen
# tou phir hm web scraping karengay public data acess kkayliyay

# %%
tables = pd.read_html('https://www.fdic.gov/bank/individual/failed/banklist.html') # only read tables
tables
# Out:
# [                                             Bank Name                City  \
#  0                     City National Bank of New Jersey              Newark
#  1                                        Resolute Bank              Maumee
#  2                                Louisa Community Bank              Louisa
#  3                                 The Enloe State Bank              Cooper
#  4                  Washington Federal Bank for Savings             Chicago
#  5      The Farmers and Merchants State Bank of Argonia             Argonia
#  6                                  Fayette County Bank          Saint Elmo
#  7    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...           Milwaukee
#  8                                       First NBC Bank         New Orleans
#  9                                        Proficio Bank  Cottonwood Heights
#  10                       Seaway Bank and Trust Company             Chicago
# ...

# %%
import requests
data = requests.get('https://www.w3schools.com')
data # give only response
# Out:
# <Response [200]>

# %%
import requests
from bs4 import BeautifulSoup
data = requests.get('https://www.w3schools.com')
response = BeautifulSoup(data.text,'html.parser') #convert response and  data to html # parser ny html mein convert kardia 
response
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <title>W3Schools Online Web Tutorials</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="HTML,CSS,JavaScript,DOM,jQuery,PHP,SQL,XML,Python,Java,Bootstrap,Web,W3CSS,W3C,tutorials,programming,development,training,learning,quiz,primer,lessons,reference,examples,source code,colors,demos,tips,w3c" name="Keywords"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="w3css/4/w3.css" rel="stylesheet"/>
# <script>
# (function() {
# var cx = '012971019331610648934:m2tou3_miwy';
# var gcse = document.createElement('script'); gcse.type = 'text/javascript'; gcse.async = true;
# gcse.src = 'https://www.google.com/cse/cse.js?cx=' + cx;
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gcse, s);
# })();
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# ...

# %%
data.text # but includes /n /r but it's not good
# Out:
# '\r\n<!DOCTYPE html>\r\n<html lang="en-US">\r\n<head>\r\n<title>W3Schools Online Web Tutorials</title>\r\n<meta charset="utf-8">\r\n<meta name="viewport" content="width=device-width, initial-scale=1">\r\n<meta name="Keywords" content="HTML,CSS,JavaScript,DOM,jQuery,PHP,SQL,XML,Python,Java,Bootstrap,Web,W3CSS,W3C,tutorials,programming,development,training,learning,quiz,primer,lessons,reference,examples,source code,colors,demos,tips,w3c">\r\n<link rel="icon" href="/favicon.ico" type="image/x-icon">\r\n<link rel="stylesheet" href="w3css/4/w3.css">\r\n<script>\r\n(function() {\r\nvar cx = \'012971019331610648934:m2tou3_miwy\';\r\nvar gcse = document.createElement(\'script\'); gcse.type = \'text/javascript\'; gcse.async = true;\r\ngcse.src = \'https://www.google.com/cse/cse.js?cx=\' + cx;\r\nvar s = document.getElementsByTagName(\'script\')[0]; s.parentNode.insertBefore(gcse, s);\r\n})();\r\n(function(i,s,o,g,r,a,m){i[\'GoogleAnalyticsObject\']=r;i[r]=i[r]||function(){\r\n(i[r].q=i[r].q||
# ...

# %%
response
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <title>W3Schools Online Web Tutorials</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="HTML,CSS,JavaScript,DOM,jQuery,PHP,SQL,XML,Python,Java,Bootstrap,Web,W3CSS,W3C,tutorials,programming,development,training,learning,quiz,primer,lessons,reference,examples,source code,colors,demos,tips,w3c" name="Keywords"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="w3css/4/w3.css" rel="stylesheet"/>
# <script>
# (function() {
# var cx = '012971019331610648934:m2tou3_miwy';
# var gcse = document.createElement('script'); gcse.type = 'text/javascript'; gcse.async = true;
# gcse.src = 'https://www.google.com/cse/cse.js?cx=' + cx;
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gcse, s);
# })();
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# ...

# %%
h1 = response.find_all('h1')
h1
# Out:
# [<h1>HTML</h1>,
#  <h1>CSS</h1>,
#  <h1>CSS</h1>,
#  <h1 class="w3-jumbo">JavaScript</h1>,
#  <h1>SQL</h1>,
#  <h1>SQL</h1>]

# %%
h1 = response.find_all('h1')
h1
# Out:
# [<h1>HTML</h1>,
#  <h1>CSS</h1>,
#  <h1>CSS</h1>,
#  <h1 class="w3-jumbo">JavaScript</h1>,
#  <h1>SQL</h1>,
#  <h1>SQL</h1>]

# %%
a = response.find_all('a') # a kay tag emin jo links haen wo chaiayay
a
# Out:
# [<a class="w3schools-logo" href="//www.w3schools.com">w3schools<span class="dotcom">.com</span></a>,
#  <a class="w3schools-logo" href="//www.w3schools.com">w3schools<span class="dotcom">.com</span></a>,
#  <a class="w3-bar-item w3-button w3-hover-white w3-padding-16 hidesm" href="javascript:void(0)" onclick="w3_open()"><i class="fa"></i></a>,
#  <a class="w3-bar-item w3-button barex w3-hover-white w3-padding-16" href="javascript:void(0)" id="navbtn_tutorials" onclick="w3_open_nav('tutorials')">TUTORIALS <i class="fa fa-caret-down"></i><i class="fa fa-caret-up" style="display:none"></i></a>,
#  <a class="w3-bar-item w3-button barex w3-hover-white w3-padding-16" href="javascript:void(0)" id="navbtn_references" onclick="w3_open_nav('references')">REFERENCES <i class="fa fa-caret-down"></i><i class="fa fa-caret-up" style="display:none"></i></a>,
# ...

# %%
import requests
from bs4 import BeautifulSoup
data = requests.get('https://www.w3schools.com')
response = BeautifulSoup(data.text,'html.parser') #convert response and  data to html # parser ny html mein convert kardia 
response
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <title>W3Schools Online Web Tutorials</title>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="HTML,CSS,JavaScript,DOM,jQuery,PHP,SQL,XML,Python,Java,Bootstrap,Web,W3CSS,W3C,tutorials,programming,development,training,learning,quiz,primer,lessons,reference,examples,source code,colors,demos,tips,w3c" name="Keywords"/>
# <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="w3css/4/w3.css" rel="stylesheet"/>
# <script>
# (function() {
# var cx = '012971019331610648934:m2tou3_miwy';
# var gcse = document.createElement('script'); gcse.type = 'text/javascript'; gcse.async = true;
# gcse.src = 'https://www.google.com/cse/cse.js?cx=' + cx;
# var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(gcse, s);
# })();
# (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# ...

# %%
response = requests.get('https://www.daraz.pk/')
daraz = BeautifulSoup(response.text, 'html.parser')
daraz
# Out:
# <!DOCTYPE HTML>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="a2a0e.home" name="spm-id"/>
# <meta content="" name="keywords"/>
# <meta content="Daraz.pk your online shopping store in Pakistan. Buy the latest Mobiles, Appliances, Fashion Accessories, &amp; more retail products available for sale online. Cash on Delivery in Karachi ✓ Lahore ✓ Islamabad ✓ All over Pakistan!" name="description"/>
# <meta content="https://www.daraz.pk/" property="og:url">
# <meta content="website" property="og:type"/>
# <meta content="Online Shopping in Pakistan: Fashion, Electronics &amp; Books - Daraz.pk" property="og:title">
# <meta content="Daraz.pk your online shopping store in Pakistan. Buy the latest Mobiles, Appliances, Fashion Accessories, &amp; more retail products available for sale online. Cash on Delivery in Karachi ✓ Lahore ✓ Islamabad ✓ All over Pakistan!" property="og:description">
# ...

# %%
img = daraz.find_all('img',class_ = 'image')
img[0] # tag ayga
# Out:
# <img alt="DarazMall" class="image" src="//laz-img-cdn.alicdn.com/images/ims-web/TB1a9RssNYaK1RjSZFnXXa80pXa.png"/>

# %%
img = daraz.find_all('img',class_ = 'image')
img[0]['src'] # image ka source ajayga
# Out:
# '//laz-img-cdn.alicdn.com/images/ims-web/TB1a9RssNYaK1RjSZFnXXa80pXa.png'

# %%
# aur source ko google mein dalen gay tou wo pic ajaygee
# matplotlib say read hojaygee pic

# %%
# web API's say data attaaa hae json form mein 
# API 
# static website ?? --- websites jo view hoaey aur sab kay pass same ayga
# dynamic website ??---- website jo user apnii userid aur password daelaein aur phir uskay baad sabb apna apna page kholain gay

# %%
API === server mein hamara userid aur passwords lay kar jay ga aur authenticate karya ga phir aapkay system ko server say connect karayga
# application proogramming interface
# API is for dynamic websites

# %%
## API hm, banaengay baad mein
